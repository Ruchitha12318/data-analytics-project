# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip
# Out:
# Usage:
#   C:\Users\ruchi\AppData\Local\Programs\Python\Python313\python.exe -m pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   inspect                     Inspect the python environment.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   index                       Inspect information available from package indexes.
#   wheel                       Build wheels from your requirements.
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv',encoding = 'ISO-8859-1')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
d={    'InvoiceNo':'invoice', 
'StockCode':'stock_code', 
'Description':'description', 
   'Quantity':'quantity',
   'InvoiceDate':'invoice_date',
       'UnitPrice':'unit_price', 
'CustomerID':'customer_id', 
'Country':'country'
}

# %%
d
# Out:
# {'InvoiceNo': 'invoice',
#  'StockCode': 'stock_code',
#  'Description': 'description',
#  'Quantity': 'quantity',
#  'InvoiceDate': 'invoice_date',
#  'UnitPrice': 'unit_price',
#  'CustomerID': 'customer_id',
#  'Country': 'country'}

# %%
df=df.rename(columns=d)

# %%
df
# Out:
#        invoice stock_code                          description  quantity  \
# 0       536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365      71053                  WHITE METAL LANTERN         6
# 2       536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...        ...                                  ...       ...
# 541904  581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905  581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587      22138        BAKING SET 9 PIECE RETROSPOT          3
#
#            invoice_date  unit_price  customer_id         country
# ...

# %%
d1={ 'InvoiceNo':'invoice_no'
   }

# %%
df=df.rename(columns=d1)

# %%
df
# Out:
#        invoice stock_code                          description  quantity  \
# 0       536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365      71053                  WHITE METAL LANTERN         6
# 2       536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...        ...                                  ...       ...
# 541904  581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905  581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587      22138        BAKING SET 9 PIECE RETROSPOT          3
#
#            invoice_date  unit_price  customer_id         country
# ...

# %%
df.head(6)
# Out:
#   invoice stock_code                          description  quantity  \
# 0  536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365      71053                  WHITE METAL LANTERN         6
# 2  536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5  536365      22752         SET 7 BABUSHKA NESTING BOXES         2
#
#      invoice_date  unit_price  customer_id         country
# 0  12/1/2010 8:26        2.55      17850.0  United Kingdom
# 1  12/1/2010 8:26        3.39      17850.0  United Kingdom
# 2  12/1/2010 8:26        2.75      17850.0  United Kingdom
# 3  12/1/2010 8:26        3.39      17850.0  United Kingdom
# 4  12/1/2010 8:26        3.39      17850.0  United Kingdom
# 5  12/1/2010 8:26        7.65      17850.0  United Kingdom

# %%
df.isna()
# Out:
#         invoice  stock_code  description  quantity  invoice_date  unit_price  \
# 0         False       False        False     False         False       False
# 1         False       False        False     False         False       False
# 2         False       False        False     False         False       False
# 3         False       False        False     False         False       False
# 4         False       False        False     False         False       False
# ...         ...         ...          ...       ...           ...         ...
# 541904    False       False        False     False         False       False
# 541905    False       False        False     False         False       False
# 541906    False       False        False     False         False       False
# 541907    False       False        False     False         False       False
# 541908    False       False        False     False         False       False
#
#         customer_id  country
# ...

# %%
df.isna().sum()
# Out:
# invoice              0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     135080
# country              0
# dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull()
# Out:
#         invoice  stock_code  description  quantity  invoice_date  unit_price  \
# 0         False       False        False     False         False       False
# 1         False       False        False     False         False       False
# 2         False       False        False     False         False       False
# 3         False       False        False     False         False       False
# 4         False       False        False     False         False       False
# ...         ...         ...          ...       ...           ...         ...
# 541904    False       False        False     False         False       False
# 541905    False       False        False     False         False       False
# 541906    False       False        False     False         False       False
# 541907    False       False        False     False         False       False
# 541908    False       False        False     False         False       False
#
#         customer_id  country
# ...

# %%
df.isna().sum().sort_values()
# Out:
# invoice              0
# stock_code           0
# quantity             0
# invoice_date         0
# country              0
# unit_price           0
# description       1454
# customer_id     135080
# dtype: int64

# %%
df.isna().sum().sort_values(ascending = False)
# Out:
# customer_id     135080
# description       1454
# stock_code           0
# invoice              0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %%
df.dtypes
# Out:
# invoice          object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %%
df.columns
# Out:
# Index(['invoice', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'customer_id', 'country'],
#       dtype='object')

# %%
df['invoice_date']=pd.to_datetime(df.invoice_date,format='%m/%d/%Y %H:%M')

# %%
df.dtypes
# Out:
# invoice                 object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id            float64
# country                 object
# dtype: object

# %%
df.head()
# Out:
#   invoice stock_code                          description  quantity  \
# 0  536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365      71053                  WHITE METAL LANTERN         6
# 2  536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %%
df.description
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: description, Length: 541909, dtype: object

# %%
df.description.str.lower()
# Out:
# 0          white hanging heart t-light holder
# 1                         white metal lantern
# 2              cream cupid hearts coat hanger
# 3         knitted union flag hot water bottle
# 4              red woolly hottie white heart.
#                          ...
# 541904            pack of 20 spaceboy napkins
# 541905           children's apron dolly girl
# 541906          childrens cutlery dolly girl
# 541907        childrens cutlery circus parade
# 541908          baking set 9 piece retrospot
# Name: description, Length: 541909, dtype: object

# %%
df.head()
# Out:
#   invoice stock_code                          description  quantity  \
# 0  536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365      71053                  WHITE METAL LANTERN         6
# 2  536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %%
df['description']=df.description.str.lower()

# %%
df.dtypes
# Out:
# invoice                 object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id            float64
# country                 object
# dtype: object

# %%
df.head()
# Out:
#   invoice stock_code                          description  quantity  \
# 0  536365     85123A   white hanging heart t-light holder         6
# 1  536365      71053                  white metal lantern         6
# 2  536365     84406B       cream cupid hearts coat hanger         8
# 3  536365     84029G  knitted union flag hot water bottle         6
# 4  536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %%
df_new=df.dropna()

# %%
df_new.isnull().sum()
# Out:
# invoice         0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# customer_id     0
# country         0
# dtype: int64

# %%
df_new.shape
# Out:
# (406829, 8)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice       406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   customer_id   406829 non-null  float64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
type(df_new)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_new=df.dropna()

# %%
df_new
# Out:
#        invoice stock_code                          description  quantity  \
# 0       536365     85123A   white hanging heart t-light holder         6
# 1       536365      71053                  white metal lantern         6
# 2       536365     84406B       cream cupid hearts coat hanger         8
# 3       536365     84029G  knitted union flag hot water bottle         6
# 4       536365     84029E       red woolly hottie white heart.         6
# ...        ...        ...                                  ...       ...
# 541904  581587      22613          pack of 20 spaceboy napkins        12
# 541905  581587      22899         children's apron dolly girl          6
# 541906  581587      23254        childrens cutlery dolly girl          4
# 541907  581587      23255      childrens cutlery circus parade         4
# 541908  581587      22138        baking set 9 piece retrospot          3
#
#               invoice_date  unit_price  customer_id         country
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice       406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   customer_id   406829 non-null  float64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
df_new.dtypes
# Out:
# invoice                 object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id            float64
# country                 object
# dtype: object

# %%
df_new.isnull().sum()
# Out:
# invoice         0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# customer_id     0
# country         0
# dtype: int64

# %%
df_new['customer_id']=df_new['customer_id'].astype('int64')
# Out:
# C:\Users\ruchi\AppData\Local\Temp\ipykernel_10528\3577090103.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['customer_id']=df_new['customer_id'].astype('int64')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_new['customer_id']=df_new['customer_id'].astype('int64')

# %%
df_new.head()
# Out:
#   invoice stock_code                          description  quantity  \
# 0  536365     85123A   white hanging heart t-light holder         6
# 1  536365      71053                  white metal lantern         6
# 2  536365     84406B       cream cupid hearts coat hanger         8
# 3  536365     84029G  knitted union flag hot water bottle         6
# 4  536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice       406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   customer_id   406829 non-null  int64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 27.9+ MB

# %%
df_new.describe()
# Out:
#             quantity                   invoice_date     unit_price  \
# count  406829.000000                         406829  406829.000000
# mean       12.061303  2011-07-10 16:30:57.879207424       3.460471
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# 50%         5.000000            2011-07-31 11:48:00       1.950000
# 75%        12.000000            2011-10-20 13:06:00       3.750000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       248.693370                            NaN      69.315162
#
#          customer_id
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
df_new['description']=df_new['description'].str.title()

# %%
df_new.head()
# Out:
#   invoice stock_code                          description  quantity  \
# 0  536365     85123A   White Hanging Heart T-Light Holder         6
# 1  536365      71053                  White Metal Lantern         6
# 2  536365     84406B       Cream Cupid Hearts Coat Hanger         8
# 3  536365     84029G  Knitted Union Flag Hot Water Bottle         6
# 4  536365     84029E       Red Woolly Hottie White Heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom

# %%
con=df_new.quantity>0

# %%
df_new=df_new[con]

# %%
df_new.describe()
# Out:
#             quantity                   invoice_date     unit_price  \
# count  397924.000000                         397924  397924.000000
# mean       13.021823  2011-07-10 23:43:36.912475648       3.116174
# min         1.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-07 11:12:00       1.250000
# 50%         6.000000            2011-07-31 14:39:00       1.950000
# 75%        12.000000            2011-10-20 14:33:00       3.750000
# max     80995.000000            2011-12-09 12:50:00    8142.750000
# std       180.420210                            NaN      22.096788
#
#          customer_id
# count  397924.000000
# mean    15294.315171
# min     12346.000000
# 25%     13969.000000
# 50%     15159.000000
# 75%     16795.000000
# max     18287.000000
# std      1713.169877

# %%
con=df_new.quantity>0

# %%
df_new=df_new[con]

# %%
df_new.describe()
# Out:
#             quantity                   invoice_date     unit_price  \
# count  397924.000000                         397924  397924.000000
# mean       13.021823  2011-07-10 23:43:36.912475648       3.116174
# min         1.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-07 11:12:00       1.250000
# 50%         6.000000            2011-07-31 14:39:00       1.950000
# 75%        12.000000            2011-10-20 14:33:00       3.750000
# max     80995.000000            2011-12-09 12:50:00    8142.750000
# std       180.420210                            NaN      22.096788
#
#          customer_id
# count  397924.000000
# mean    15294.315171
# min     12346.000000
# 25%     13969.000000
# 50%     15159.000000
# 75%     16795.000000
# max     18287.000000
# std      1713.169877

# %%
df_new.describe().round(2)
# Out:
#         quantity                   invoice_date  unit_price  customer_id
# count  397924.00                         397924   397924.00    397924.00
# mean       13.02  2011-07-10 23:43:36.912475648        3.12     15294.32
# min         1.00            2010-12-01 08:26:00        0.00     12346.00
# 25%         2.00            2011-04-07 11:12:00        1.25     13969.00
# 50%         6.00            2011-07-31 14:39:00        1.95     15159.00
# 75%        12.00            2011-10-20 14:33:00        3.75     16795.00
# max     80995.00            2011-12-09 12:50:00     8142.75     18287.00
# std       180.42                            NaN       22.10      1713.17

# %%
df_new.shape
# Out:
# (397924, 8)

# %% [markdown]
# #adding new column amount spent

# %%
df_new['amount_spent']=df_new['quantity']*df_new['unit_price']

# %%
df_new
# Out:
#        invoice stock_code                          description  quantity  \
# 0       536365     85123A   White Hanging Heart T-Light Holder         6
# 1       536365      71053                  White Metal Lantern         6
# 2       536365     84406B       Cream Cupid Hearts Coat Hanger         8
# 3       536365     84029G  Knitted Union Flag Hot Water Bottle         6
# 4       536365     84029E       Red Woolly Hottie White Heart.         6
# ...        ...        ...                                  ...       ...
# 541904  581587      22613          Pack Of 20 Spaceboy Napkins        12
# 541905  581587      22899         Children'S Apron Dolly Girl          6
# 541906  581587      23254        Childrens Cutlery Dolly Girl          4
# 541907  581587      23255      Childrens Cutlery Circus Parade         4
# 541908  581587      22138        Baking Set 9 Piece Retrospot          3
#
#               invoice_date  unit_price  customer_id         country  \
# ...

# %%
df_new['invoice_date']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[ns]

# %%
df_new['invoice_date'].dt.year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541904    2011
# 541905    2011
# 541906    2011
# 541907    2011
# 541908    2011
# Name: invoice_date, Length: 397924, dtype: int32

# %%
c1='yearmonth'

# %%
v1=df_new['invoice_date'].map(lambda col:100*(col.year)+col.month)

# %%
df_new.insert(loc=2,column=c1,value=v1)

# %%
df_new
# Out:
#        invoice stock_code  yearmonth                          description  \
# 0       536365     85123A     201012   White Hanging Heart T-Light Holder
# 1       536365      71053     201012                  White Metal Lantern
# 2       536365     84406B     201012       Cream Cupid Hearts Coat Hanger
# 3       536365     84029G     201012  Knitted Union Flag Hot Water Bottle
# 4       536365     84029E     201012       Red Woolly Hottie White Heart.
# ...        ...        ...        ...                                  ...
# 541904  581587      22613     201112          Pack Of 20 Spaceboy Napkins
# 541905  581587      22899     201112         Children'S Apron Dolly Girl
# 541906  581587      23254     201112        Childrens Cutlery Dolly Girl
# 541907  581587      23255     201112      Childrens Cutlery Circus Parade
# 541908  581587      22138     201112        Baking Set 9 Piece Retrospot
#
#         quantity        invoice_date  unit_price  customer_id         country  \
# ...

# %%
df_new
# Out:
#        invoice stock_code  yearmonth                          description  \
# 0       536365     85123A     201012   White Hanging Heart T-Light Holder
# 1       536365      71053     201012                  White Metal Lantern
# 2       536365     84406B     201012       Cream Cupid Hearts Coat Hanger
# 3       536365     84029G     201012  Knitted Union Flag Hot Water Bottle
# 4       536365     84029E     201012       Red Woolly Hottie White Heart.
# ...        ...        ...        ...                                  ...
# 541904  581587      22613     201112          Pack Of 20 Spaceboy Napkins
# 541905  581587      22899     201112         Children'S Apron Dolly Girl
# 541906  581587      23254     201112        Childrens Cutlery Dolly Girl
# 541907  581587      23255     201112      Childrens Cutlery Circus Parade
# 541908  581587      22138     201112        Baking Set 9 Piece Retrospot
#
#         quantity        invoice_date  unit_price  customer_id         country  \
# ...

# %%
type(df_new)
# Out:
# pandas.core.frame.DataFrame

# %%
df_new
# Out:
#        invoice stock_code  yearmonth                          description  \
# 0       536365     85123A     201012   White Hanging Heart T-Light Holder
# 1       536365      71053     201012                  White Metal Lantern
# 2       536365     84406B     201012       Cream Cupid Hearts Coat Hanger
# 3       536365     84029G     201012  Knitted Union Flag Hot Water Bottle
# 4       536365     84029E     201012       Red Woolly Hottie White Heart.
# ...        ...        ...        ...                                  ...
# 541904  581587      22613     201112          Pack Of 20 Spaceboy Napkins
# 541905  581587      22899     201112         Children'S Apron Dolly Girl
# 541906  581587      23254     201112        Childrens Cutlery Dolly Girl
# 541907  581587      23255     201112      Childrens Cutlery Circus Parade
# 541908  581587      22138     201112        Baking Set 9 Piece Retrospot
#
#         quantity        invoice_date  unit_price  customer_id         country  \
# ...

# %%
c2='month'

# %%
v2=df_new.invoice_date.dt.month

# %%
print(df_new)
# Out:
#        invoice stock_code  yearmonth                          description  \
# 0       536365     85123A     201012   White Hanging Heart T-Light Holder
# 1       536365      71053     201012                  White Metal Lantern
# 2       536365     84406B     201012       Cream Cupid Hearts Coat Hanger
# 3       536365     84029G     201012  Knitted Union Flag Hot Water Bottle
# 4       536365     84029E     201012       Red Woolly Hottie White Heart.
# ...        ...        ...        ...                                  ...
# 541904  581587      22613     201112          Pack Of 20 Spaceboy Napkins
# 541905  581587      22899     201112         Children'S Apron Dolly Girl
# 541906  581587      23254     201112        Childrens Cutlery Dolly Girl
# 541907  581587      23255     201112      Childrens Cutlery Circus Parade
# 541908  581587      22138     201112        Baking Set 9 Piece Retrospot
#
#         quantity        invoice_date  unit_price  customer_id         country  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df_new=df.dropna()

# %%
df_new.head()
# Out:
#   invoice stock_code                          description  quantity  \
# 0  536365     85123A   white hanging heart t-light holder         6
# 1  536365      71053                  white metal lantern         6
# 2  536365     84406B       cream cupid hearts coat hanger         8
# 3  536365     84029G  knitted union flag hot water bottle         6
# 4  536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %%
df_new.shape
# Out:
# (406829, 8)

# %%
df_new.dtypes
# Out:
# invoice                 object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id            float64
# country                 object
# dtype: object

# %%
df_new['customer_id']=df_new['customer_id'].astype('int64')

# %%
df_new.dtypes
# Out:
# invoice                 object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id              int64
# country                 object
# dtype: object

# %%
df_new.head()
# Out:
#   invoice stock_code                          description  quantity  \
# 0  536365     85123A   white hanging heart t-light holder         6
# 1  536365      71053                  white metal lantern         6
# 2  536365     84406B       cream cupid hearts coat hanger         8
# 3  536365     84029G  knitted union flag hot water bottle         6
# 4  536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom

# %%
c1='year_month'

# %%
v1=df_new['invoice_date'].map(lambda col: 100*(col.year)+col.month)

# %%
df_new.insert(loc=2,column=c1,value=v1)

# %%
df_new
# Out:
#        invoice stock_code  year_month                          description  \
# 0       536365     85123A      201012   white hanging heart t-light holder
# 1       536365      71053      201012                  white metal lantern
# 2       536365     84406B      201012       cream cupid hearts coat hanger
# 3       536365     84029G      201012  knitted union flag hot water bottle
# 4       536365     84029E      201012       red woolly hottie white heart.
# ...        ...        ...         ...                                  ...
# 541904  581587      22613      201112          pack of 20 spaceboy napkins
# 541905  581587      22899      201112         children's apron dolly girl
# 541906  581587      23254      201112        childrens cutlery dolly girl
# 541907  581587      23255      201112      childrens cutlery circus parade
# 541908  581587      22138      201112        baking set 9 piece retrospot
#
# ...

# %%
c2='month'

# %%
c3='day'

# %%
c4='hour'

# %%
v2=df_new.invoice_date.dt.month

# %%
v3=df_new.invoice_date.dt.day

# %%
v4=df_new.invoice_date.dt.hour

# %%
df_new.insert(loc=3,column=c2,value=v2)
df_new.insert(loc=4,column=c3,value=v3)
df_new.insert(loc=5,column=c4,value=v4)

# %%
df_new
# Out:
#        invoice stock_code  year_month  month  day  hour  \
# 0       536365     85123A      201012     12    1     8
# 1       536365      71053      201012     12    1     8
# 2       536365     84406B      201012     12    1     8
# 3       536365     84029G      201012     12    1     8
# 4       536365     84029E      201012     12    1     8
# ...        ...        ...         ...    ...  ...   ...
# 541904  581587      22613      201112     12    9    12
# 541905  581587      22899      201112     12    9    12
# 541906  581587      23254      201112     12    9    12
# 541907  581587      23255      201112     12    9    12
# 541908  581587      22138      201112     12    9    12
#
#                                 description  quantity        invoice_date  \
# 0        white hanging heart t-light holder         6 2010-12-01 08:26:00
# 1                       white metal lantern         6 2010-12-01 08:26:00
# ...

# %%
df_new.describe()
# Out:
#           year_month          month            day           hour  \
# count  406829.000000  406829.000000  406829.000000  406829.000000
# mean   201101.006123       7.605947      15.036128      12.737472
# min    201012.000000       1.000000       1.000000       6.000000
# 25%    201104.000000       5.000000       7.000000      11.000000
# 50%    201107.000000       8.000000      15.000000      13.000000
# 75%    201110.000000      11.000000      22.000000      14.000000
# max    201112.000000      12.000000      31.000000      20.000000
# std        23.877089       3.418942       8.653730       2.284952
#
#             quantity                   invoice_date     unit_price  \
# count  406829.000000                         406829  406829.000000
# mean       12.061303  2011-07-10 16:30:57.879207424       3.460471
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# ...

# %%
con=df_new.quantity>0

# %%
df_new=df_new[con]

# %%
df_new
# Out:
#        invoice stock_code  year_month  month  day  hour  \
# 0       536365     85123A      201012     12    1     8
# 1       536365      71053      201012     12    1     8
# 2       536365     84406B      201012     12    1     8
# 3       536365     84029G      201012     12    1     8
# 4       536365     84029E      201012     12    1     8
# ...        ...        ...         ...    ...  ...   ...
# 541904  581587      22613      201112     12    9    12
# 541905  581587      22899      201112     12    9    12
# 541906  581587      23254      201112     12    9    12
# 541907  581587      23255      201112     12    9    12
# 541908  581587      22138      201112     12    9    12
#
#                                 description  quantity        invoice_date  \
# 0        white hanging heart t-light holder         6 2010-12-01 08:26:00
# 1                       white metal lantern         6 2010-12-01 08:26:00
# ...

# %%
df_new.shape
# Out:
# (397924, 12)

# %%
df_new['description']=df_new.description.str.title()

# %%
df_new.head()
# Out:
#   invoice stock_code  year_month  month  day  hour  \
# 0  536365     85123A      201012     12    1     8
# 1  536365      71053      201012     12    1     8
# 2  536365     84406B      201012     12    1     8
# 3  536365     84029G      201012     12    1     8
# 4  536365     84029E      201012     12    1     8
#
#                            description  quantity        invoice_date  \
# 0   White Hanging Heart T-Light Holder         6 2010-12-01 08:26:00
# 1                  White Metal Lantern         6 2010-12-01 08:26:00
# 2       Cream Cupid Hearts Coat Hanger         8 2010-12-01 08:26:00
# 3  Knitted Union Flag Hot Water Bottle         6 2010-12-01 08:26:00
# 4       Red Woolly Hottie White Heart.         6 2010-12-01 08:26:00
#
#    unit_price  customer_id         country
# 0        2.55        17850  United Kingdom
# 1        3.39        17850  United Kingdom
# 2        2.75        17850  United Kingdom
# 3        3.39        17850  United Kingdom
# ...

# %%
df_new['amount_spent']=df_new['quantity']*df_new['unit_price']

# %%
df_new
# Out:
#        invoice stock_code  year_month  month  day  hour  \
# 0       536365     85123A      201012     12    1     8
# 1       536365      71053      201012     12    1     8
# 2       536365     84406B      201012     12    1     8
# 3       536365     84029G      201012     12    1     8
# 4       536365     84029E      201012     12    1     8
# ...        ...        ...         ...    ...  ...   ...
# 541904  581587      22613      201112     12    9    12
# 541905  581587      22899      201112     12    9    12
# 541906  581587      23254      201112     12    9    12
# 541907  581587      23255      201112     12    9    12
# 541908  581587      22138      201112     12    9    12
#
#                                 description  quantity        invoice_date  \
# 0        White Hanging Heart T-Light Holder         6 2010-12-01 08:26:00
# 1                       White Metal Lantern         6 2010-12-01 08:26:00
# ...

# %%
df_new.groupby(by=['customer_id']).count()
# Out:
#              invoice  stock_code  year_month  month  day  hour  description  \
# customer_id
# 12346              1           1           1      1    1     1            1
# 12347            182         182         182    182  182   182          182
# 12348             31          31          31     31   31    31           31
# 12349             73          73          73     73   73    73           73
# 12350             17          17          17     17   17    17           17
# ...              ...         ...         ...    ...  ...   ...          ...
# 18280             10          10          10     10   10    10           10
# 18281              7           7           7      7    7     7            7
# 18282             12          12          12     12   12    12           12
# 18283            756         756         756    756  756   756          756
# 18287             70          70          70     70   70    70           70
#
# ...

# %%
df_new.groupby(by=['customer_id','country']).count()
# Out:
#                             invoice  stock_code  year_month  month  day  hour  \
# customer_id country
# 12346       United Kingdom        1           1           1      1    1     1
# 12347       Iceland             182         182         182    182  182   182
# 12348       Finland              31          31          31     31   31    31
# 12349       Italy                73          73          73     73   73    73
# 12350       Norway               17          17          17     17   17    17
# ...                             ...         ...         ...    ...  ...   ...
# 18280       United Kingdom       10          10          10     10   10    10
# 18281       United Kingdom        7           7           7      7    7     7
# 18282       United Kingdom       12          12          12     12   12    12
# 18283       United Kingdom      756         756         756    756  756   756
# 18287       United Kingdom       70          70          70     70   70    70
#
# ...

# %%
df_new.groupby(by=['customer_id','country'])['invoice'].count()
# Out:
# customer_id  country
# 12346        United Kingdom      1
# 12347        Iceland           182
# 12348        Finland            31
# 12349        Italy              73
# 12350        Norway             17
#                               ...
# 18280        United Kingdom     10
# 18281        United Kingdom      7
# 18282        United Kingdom     12
# 18283        United Kingdom    756
# 18287        United Kingdom     70
# Name: invoice, Length: 4347, dtype: int64

# %%
df_new.groupby(by=['customer_id','country'],as_index=False)['invoice'].count()
# Out:
#       customer_id         country  invoice
# 0           12346  United Kingdom        1
# 1           12347         Iceland      182
# 2           12348         Finland       31
# 3           12349           Italy       73
# 4           12350          Norway       17
# ...           ...             ...      ...
# 4342        18280  United Kingdom       10
# 4343        18281  United Kingdom        7
# 4344        18282  United Kingdom       12
# 4345        18283  United Kingdom      756
# 4346        18287  United Kingdom       70
#
# [4347 rows x 3 columns]

# %%
# !pip install matplotlib
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.1 MB 2.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.3/8.1 MB 2.4 MB/s eta 0:00:03
#    --------- ------------------------------ 1.8/8.1 MB 2.5 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.1 MB 3.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 4.4 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 4.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------- ----------- 1.6/2.2 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 6.5 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_new.groupby(by=['customer_id','country'],as_index=False)['invoice'].count()
# Out:
#       customer_id         country  invoice
# 0           12346  United Kingdom        1
# 1           12347         Iceland      182
# 2           12348         Finland       31
# 3           12349           Italy       73
# 4           12350          Norway       17
# ...           ...             ...      ...
# 4342        18280  United Kingdom       10
# 4343        18281  United Kingdom        7
# 4344        18282  United Kingdom       12
# 4345        18283  United Kingdom      756
# 4346        18287  United Kingdom       70
#
# [4347 rows x 3 columns]

# %%
orders=df_new.groupby(by=['customer_id','country'],as_index=False)['invoice'].count()

# %%
df_new
# Out:
#        invoice stock_code  year_month  month  day  hour  \
# 0       536365     85123A      201012     12    1     8
# 1       536365      71053      201012     12    1     8
# 2       536365     84406B      201012     12    1     8
# 3       536365     84029G      201012     12    1     8
# 4       536365     84029E      201012     12    1     8
# ...        ...        ...         ...    ...  ...   ...
# 541904  581587      22613      201112     12    9    12
# 541905  581587      22899      201112     12    9    12
# 541906  581587      23254      201112     12    9    12
# 541907  581587      23255      201112     12    9    12
# 541908  581587      22138      201112     12    9    12
#
#                                 description  quantity        invoice_date  \
# 0        White Hanging Heart T-Light Holder         6 2010-12-01 08:26:00
# 1                       White Metal Lantern         6 2010-12-01 08:26:00
# ...

# %%
orders.sort_values(by='invoice',ascending=False).head()
# Out:
#       customer_id         country  invoice
# 4019        17841  United Kingdom     7847
# 1888        14911            EIRE     5677
# 1298        14096  United Kingdom     5111
# 334         12748  United Kingdom     4596
# 1670        14606  United Kingdom     2700

# %% [markdown]
# # visualizing-number of orders for different customers

# %%
orders=df_new.groupby(by=['customer_id','country'],as_index=False)['invoice'].count()
plt.subplots(figsize=(15,6))
plt.plot(orders.customer_id,orders.invoice)
plt.xlabel('Customers ID')
plt.ylabel('number of Orders for different Customers')
# Out:
# Text(0, 0.5, 'number of Orders for different Customers')

# %% [markdown]
# #how much money spent by each customer

# %%
df_new.groupby(by=['customer_id','country'])['amount_spent'].sum()
# Out:
# customer_id  country
# 12346        United Kingdom    77183.60
# 12347        Iceland            4310.00
# 12348        Finland            1797.24
# 12349        Italy              1757.55
# 12350        Norway              334.40
#                                  ...
# 18280        United Kingdom      180.60
# 18281        United Kingdom       80.82
# 18282        United Kingdom      178.05
# 18283        United Kingdom     2094.88
# 18287        United Kingdom     1837.28
# Name: amount_spent, Length: 4347, dtype: float64

# %% [markdown]
# #top ten customers who spend highest money

# %%
amount_spent.sort_values(by='amount_spent',ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 amount_spent.sort_values(by='amount_spent',ascending=False).head(10)
#
# NameError: name 'amount_spent' is not defined

# %%
df_new
# Out:
#        invoice stock_code  year_month  month  day  hour  \
# 0       536365     85123A      201012     12    1     8
# 1       536365      71053      201012     12    1     8
# 2       536365     84406B      201012     12    1     8
# 3       536365     84029G      201012     12    1     8
# 4       536365     84029E      201012     12    1     8
# ...        ...        ...         ...    ...  ...   ...
# 541904  581587      22613      201112     12    9    12
# 541905  581587      22899      201112     12    9    12
# 541906  581587      23254      201112     12    9    12
# 541907  581587      23255      201112     12    9    12
# 541908  581587      22138      201112     12    9    12
#
#                                 description  quantity        invoice_date  \
# 0        White Hanging Heart T-Light Holder         6 2010-12-01 08:26:00
# 1                       White Metal Lantern         6 2010-12-01 08:26:00
# ...
